# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# /home/anishthite/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
import pandas as pd

# %%
df1 = pd.read_csv('results-20200305-223056.csv')
df2 = pd.read_csv('results-20200305-223121.csv')
df3 = pd.read_csv('results-20200305-223140.csv')
df4 = pd.read_csv('results-20200305-223156.csv')
df5 = pd.read_csv('results-20200305-223216.csv')
df6 = pd.read_csv('results-20200305-223237.csv')
df7 = pd.read_csv('results-20200305-223316.csv')
df8 = pd.read_csv('results-20200305-223332.csv')
df9 = pd.read_csv('results-20200305-223349.csv')
df10 = pd.read_csv('results-20200305-223407.csv')
df11 = pd.read_csv('results-20200305-223637.csv')
df12 = pd.read_csv('results-20200306-014412.csv')
df13 = pd.read_csv('results-20200306-014434.csv')
df14 = pd.read_csv('results-20200306-014516.csv')
df15 = pd.read_csv('results-20200306-014530.csv')
df16 = pd.read_csv('results-20200306-014553.csv')
df17 = pd.read_csv('results-20200306-014724.csv')
df18 = pd.read_csv('results-20200306-014759.csv')
df19 = pd.read_csv('results-20200306-014808.csv')
df20 = pd.read_csv('results-20200306-014822.csv')
df21 = pd.read_csv('results-20200306-014849.csv')
df22 = pd.read_csv('results-20200306-014903.csv')
df23 = pd.read_csv('results-20200306-014919.csv')
df24 = pd.read_csv('results-20200306-015846.csv')
df25 = pd.read_csv('results-20200306-015942.csv')
df26 = pd.read_csv('results-20200306-020002.csv')

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26]
df = pd.concat(frames)

# %%
df
# Out:
#                                                                                                                                                                           selftext  \
# 0      If the Royal Guard spend so much time around the Soul King, how did they not notice/realize that Pernida and Gerard were parts of the Soul King? Or did I just miss it.
# 1      El otro día tuve una discusión con un grupo de amigos, sobre cómo se le diría. Agua muerta? Agua viva muerta? No pudimos ponernos de acuerdo
# 2      I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3      I literally can't even right now.\n\nNow that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 4      Do you people want small tweaks? New bosses? Make some of those item ideas a reality? Make "The Binding Of Bloat"?
# ...

# %%
df = df[df['selftext'].str[-1:] == '?']

# %%
df
# Out:
#                                                                                                                                                                                                   selftext  \
# 2      I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3      I literally can't even right now.\n\nNow that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 6      ?
# 7      Seriously, George has only been gone for like 7 years and now this Jeb guy is whoring for more attention to their family. How can we put an end to this?
# 10     Is it deemed acceptable to join an opposing clan to scout their war bases if they have their clan settings set to "anyone can join"?
# ...                                                                                                                                     ...
# ...

# %%
df = df[df['body'] != '[removed]']

# %%
df
# Out:
#                                                                                                                                                                                          selftext  \
# 2      I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3      I literally can't even right now.\n\nNow that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 6      ?
# 7      Seriously, George has only been gone for like 7 years and now this Jeb guy is whoring for more attention to their family. How can we put an end to this?
# 10     Is it deemed acceptable to join an opposing clan to scout their war bases if they have their clan settings set to "anyone can join"?
# ...                                                                                                                                     ...
# ...

# %%
df = df[df['body'] != '[deleted]']

# %%
df
# Out:
#                                                                                                                                                                                     selftext  \
# 2      I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3      I literally can't even right now.\n\nNow that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 6      ?
# 7      Seriously, George has only been gone for like 7 years and now this Jeb guy is whoring for more attention to their family. How can we put an end to this?
# 10     Is it deemed acceptable to join an opposing clan to scout their war bases if they have their clan settings set to "anyone can join"?
# ...                                                                                                                                     ...
# ...

# %%
df = df[df['selftext'] != '?']

# %%
df
# Out:
#                                                                                                                                                                                     selftext  \
# 2      I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3      I literally can't even right now.\n\nNow that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 7      Seriously, George has only been gone for like 7 years and now this Jeb guy is whoring for more attention to their family. How can we put an end to this?
# 10     Is it deemed acceptable to join an opposing clan to scout their war bases if they have their clan settings set to "anyone can join"?
# 11     *Sasha, having left the medbay, heads over to the cafe. She has a dinner party in mind for the night, and needs help*\n\nHmm... I wonder if Vish'll help me?
# ...

# %%
df = df[df['selftext'].str.count(r'\?') == 1]

# %%
df
# Out:
#                                                                                                                                                                                       selftext  \
# 2      I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3      I literally can't even right now.\n\nNow that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 7      Seriously, George has only been gone for like 7 years and now this Jeb guy is whoring for more attention to their family. How can we put an end to this?
# 10     Is it deemed acceptable to join an opposing clan to scout their war bases if they have their clan settings set to "anyone can join"?
# 11     *Sasha, having left the medbay, heads over to the cafe. She has a dinner party in mind for the night, and needs help*\n\nHmm... I wonder if Vish'll help me?
# ...

# %%
df['selftext'] = df['selftext'].str.replace('\n', '')
df['body'] = df['body'].str.replace('\n', '')
# Out:
# /home/anishthite/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/anishthite/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#                                                                                                                                                                                       selftext  \
# 2      I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3      I literally can't even right now.Now that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 7      Seriously, George has only been gone for like 7 years and now this Jeb guy is whoring for more attention to their family. How can we put an end to this?
# 10     Is it deemed acceptable to join an opposing clan to scout their war bases if they have their clan settings set to "anyone can join"?
# 11     *Sasha, having left the medbay, heads over to the cafe. She has a dinner party in mind for the night, and needs help*Hmm... I wonder if Vish'll help me?
# ...

# %%
df.to_csv('negative_examples.tsv',sep='\t',index=False, header=False)

# %%
newdf = df[:117273]

# %%
newdf
# Out:
#                                                                                                                                                                selftext  \
# 2     I'm down 17% because of a shit stock called SUNE. What about you guys?
# 3     I literally can't even right now.Now that spoilers for Granblue might be coming fairly regularly I can't keep patient. How do you wait for so long and stay sane?
# 7     Seriously, George has only been gone for like 7 years and now this Jeb guy is whoring for more attention to their family. How can we put an end to this?
# 10    Is it deemed acceptable to join an opposing clan to scout their war bases if they have their clan settings set to "anyone can join"?
# 11    *Sasha, having left the medbay, heads over to the cafe. She has a dinner party in mind for the night, and needs help*Hmm... I wonder if Vish'll help me?
# ...

# %%
newdf.to_csv('negative_examples_adj.tsv',sep='\t',index=False, header=False)
